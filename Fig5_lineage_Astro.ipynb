# %%
# %pylab inline

import warnings
warnings.filterwarnings("ignore")

from SCCAF import *
import scanpy as sc
import scVelo as svc
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sc.__version__
# Out:
# '1.4.6'

# %%
ad = sc.read('data/FM_hippo_221150_wk.h5')

# %%
ad_sub = ad[~ad.obs['label_13'].isin(['doublets', 'doublets_1',
       'doublets_Astro_OPC', 'doublets_MG_OPC']),:]
matplotlib.rcParams.update({'font.size': 10})
fig = plt.figure(constrained_layout=True,figsize=(5,5))
#sns.despine()

gs = GridSpec(1, 1, figure=fig)
#ax1 = fig.add_subplot(gs[0, 0:])
ax2 = fig.add_subplot(gs[0, 0])
#ax1.annotate('a', (-1,1.05), size=5, xycoords=ax1.get_xaxis_transform(), weight='bold')
#ax2.annotate('b', (-42,1.03), size=15, xycoords=ax2.get_xaxis_transform(), weight='bold')
#ax6.annotate('c', (0,1.01), size=5, xycoords=ax6.get_xaxis_transform(), weight='bold')

#ax1.imshow(fig1a)
#ax1.set_axis_off()

ax2 = sc.pl.umap(ad_sub, color=['show_Astro'],ax=ax2,legend_loc = None,\
           legend_fontsize=10,title=' ', show=False, size=5, frameon = False)

#ax2.spines['bottom'].set_color('#000000')
#ax2.spines['left'].set_color('#000000') 
#ax2.spines['top'].set_color('#FFFFFF')
#ax2.spines['right'].set_color('#FFFFFF')
#ax2.set_facecolor('white')

#ax2.xaxis.label.set_size(12)
#ax2.yaxis.label.set_size(12)

# %%
ad_zc = sc.read('toAstro2_v.h5')

# %%
ad_zc
# Out:
# AnnData object with n_obs × n_vars = 19430 × 2000
#     obs: 'RNA_type', 'age', 'batch', 'batch_orig', 'cell_number', 'date', 'doublet_rate', 'sample', 'scrub_scores', 'scurb_doublets', 'sex', 'suffix', 'percent_mito', 'n_counts', 'n_genes', 'tenX_version', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'cell', 'Hochgerner1', 'Hochgerner2', 'leiden', 'cell1', 'leiden_r1.5', 'cell2', 'cell3', 'cell4', 'cell5', 'cell6', 'cell7', 'cell8', 'y', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'velocity_self_transition'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'fit_r2', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_', 'fit_scaling', 'fit_std_u', 'fit_std_s', 'fit_likelihood', 'fit_u0', 'fit_s0', 'fit_pval_steady', 'fit_steady_u', 'fit_steady_s', 'fit_variance', 'fit_alignment_scaling', 'velocity_genes'
#     uns: 'age_colors', 'batch_colors', 'cell1_colors', 'cell2_colors', 'cell3_colors', 'cell4_colors', 'cell7_colors', 'cell8_colors', 'cell8_sizes', 'cell_colors', 'draw_graph', 'hvg', 'leiden', 'leiden_colors', 'leiden_r1.5_colors', 'neighbors', 'paga', 'pca', 'rank_genes_groups', 'recover_dynamics', 'tenX_version_colors', 'umap', 'velocity_graph', 'velocity_graph_neg', 'velocity_params'
#     obsm: 'X_draw_graph_fa', 'X_harmonypca', 'X_pca', 'X_umap', 'X_umapharmony', 'X_umapraw', 'velocity_draw_graph_fa', 'velocity_umap'
#     varm: 'PCs', 'loss'
#     layers: 'Ms', 'Mu', 'ambiguous', 'fit_t', 'fit_tau', 'fit_tau_', 'matrix', 'spliced', 'unspliced', 'velocity', 'velocity_u'
#     obsp: 'connectivities', 'distances'

# %%
figsize(5,5)
scv.pl.velocity_embedding_stream(ad_zc, basis='umap', color = 'label9',\
                                 title = ' ', alpha = 0.1, s = 50, legend_fontoutline = 3,\
                                 save  = "Fig_Astro_velo.png",dpi = 600, legend_fontsize = 16)
# Out:
# saving figure to file ./figures/scvelo_Fig_Astro_velo.png

# %%
ad_zc
# Out:
# AnnData object with n_obs × n_vars = 19430 × 2000
#     obs: 'RNA_type', 'age', 'batch', 'batch_orig', 'cell_number', 'date', 'doublet_rate', 'sample', 'scrub_scores', 'scurb_doublets', 'sex', 'suffix', 'percent_mito', 'n_counts', 'n_genes', 'tenX_version', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'cell', 'Hochgerner1', 'Hochgerner2', 'leiden', 'cell1', 'leiden_r1.5', 'cell2', 'cell3', 'cell4', 'cell5', 'cell6', 'cell7', 'cell8', 'y', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'velocity_self_transition', 'label9'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'fit_r2', 'fit_alpha', 'fit_beta', 'fit_gamma', 'fit_t_', 'fit_scaling', 'fit_std_u', 'fit_std_s', 'fit_likelihood', 'fit_u0', 'fit_s0', 'fit_pval_steady', 'fit_steady_u', 'fit_steady_s', 'fit_variance', 'fit_alignment_scaling', 'velocity_genes'
#     uns: 'age_colors', 'batch_colors', 'cell1_colors', 'cell2_colors', 'cell3_colors', 'cell4_colors', 'cell7_colors', 'cell8_colors', 'cell8_sizes', 'cell_colors', 'draw_graph', 'hvg', 'leiden', 'leiden_colors', 'leiden_r1.5_colors', 'neighbors', 'paga', 'pca', 'rank_genes_groups', 'recover_dynamics', 'tenX_version_colors', 'umap', 'velocity_graph', 'velocity_graph_neg', 'velocity_params', 'label9_colors'
#     obsm: 'X_draw_graph_fa', 'X_harmonypca', 'X_pca', 'X_umap', 'X_umapharmony', 'X_umapraw', 'velocity_draw_graph_fa', 'velocity_umap'
#     varm: 'PCs', 'loss'
#     layers: 'Ms', 'Mu', 'ambiguous', 'fit_t', 'fit_tau', 'fit_tau_', 'matrix', 'spliced', 'unspliced', 'velocity', 'velocity_u'
#     obsp: 'connectivities', 'distances'

# %%
matplotlib.rcParams.update({'font.size': 10})
fig = plt.figure(figsize=(5.5,5))
#sns.despine()

gs = GridSpec(1, 1, figure=fig)
#ax1 = fig.add_subplot(gs[0, 0:])
ax2 = fig.add_subplot(gs[0, 0])
#ax1.annotate('a', (-1,1.05), size=5, xycoords=ax1.get_xaxis_transform(), weight='bold')
#ax2.annotate('b', (-42,1.03), size=15, xycoords=ax2.get_xaxis_transform(), weight='bold')
#ax6.annotate('c', (0,1.01), size=5, xycoords=ax6.get_xaxis_transform(), weight='bold')

#ax1.imshow(fig1a)
#ax1.set_axis_off()

ax2 = scv.pl.scatter(ad_zc, color='latent_time', color_map='coolwarm',\
                     title = ' ', size=20, ax = ax2, show = False, vmin =-0, vmax = 0.9)

#ax2.spines['bottom'].set_color('#000000')
#ax2.spines['left'].set_color('#000000') 
#ax2.spines['top'].set_color('#FFFFFF')
#ax2.spines['right'].set_color('#FFFFFF')
#ax2.set_facecolor('white')

#ax2.xaxis.label.set_size(12)
#ax2.yaxis.label.set_size(12)


#fig.tight_layout(w_pad=0.3)
#plt.show()
plt.savefig("Figure/V4/Fig4_Astro_OPC/Fig_Astro_umap_latent.pdf", dpi = 200)
plt.savefig("Figure/V4/Fig4_Astro_OPC/Fig_Astro_umap_latent.png", dpi = 600)

# %%
matplotlib.rcParams.update({'font.size': 10})
fig = plt.figure(figsize=(9.5,1.8))
#sns.despine()

gs = GridSpec(1,4, figure=fig)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])
ax4 = fig.add_subplot(gs[0, 3])

#ax1.annotate('a', (-1,1.05), size=5, xycoords=ax1.get_xaxis_transform(), weight='bold')
#ax2.annotate('b', (-42,1.03), size=15, xycoords=ax2.get_xaxis_transform(), weight='bold')
#ax6.annotate('c', (0,1.01), size=5, xycoords=ax6.get_xaxis_transform(), weight='bold')

#ax1.imshow(fig1a)
#ax1.set_axis_off()
cm = 'RdGy_r'

ax1 = sc.pl.umap(ad_zc, color = 'FLI1', title = 'FLI1',
                    color_map=cm,ax = ax1, frameon = False, show = False, vmin = -1, vmax = 1.5, s = 10)

ax2 = sc.pl.umap(ad_zc, color = 'CALY',title = 'CALY', 
                    color_map=cm,ax = ax2, frameon = False, show = False, vmin = -2, vmax = 4)

#ax3 = sc.pl.umap(ad_zc, color = 'GRIN1',title = 'GRIN1',
#                    color_map=cm,ax = ax3, frameon = False, show = False, vmin = -1.5, vmax = 3)

ax3 = sc.pl.umap(ad_zc, color = 'SLC14A1',title = 'SLC14A1',
                    color_map=cm,ax = ax3, frameon = False, show = False, vmin = -1.5, vmax = 3)
ax4 = sc.pl.umap(ad_zc, color = 'SLC1A3',title = 'SLC1A3',
                    color_map=cm,ax = ax4, frameon = False, show = False, vmin = -2.3, vmax = 7)



#ax2.spines['bottom'].set_color('#000000')
#ax2.spines['left'].set_color('#000000') 
#ax2.spines['top'].set_color('#FFFFFF')
#ax2.spines['right'].set_color('#FFFFFF')
#ax2.set_facecolor('white')

#ax2.xaxis.label.set_size(12)
#ax2.yaxis.label.set_size(12)


#fig.tight_layout(w_pad=0.3)
#plt.show()
plt.savefig("Figure/V6_cell/Fig4_Astro_OPC/Fig_Astro_umap_4marker.pdf", dpi = 200)
plt.savefig("Figure/V6_cell/Fig4_Astro_OPC/Fig_Astro_umap_4marker.png", dpi = 600)
