# %%
# %pylab inline

import warnings
warnings.filterwarnings("ignore")

from SCCAF import *
import scanpy as sc
import scVelo as svc
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sc.__version__
# Out:
# '1.4.6'

# %%
#ad = sc.read('data/FM_hippo_221150_wk.h5')
ad = sc.read('data/FM_hippo_215395_wk.h5')

# %%
ad_sub = ad[~ad.obs['label_13'].isin(['doublets', 'doublets_1',
       'doublets_Astro_OPC', 'doublets_MG_OPC']),:]

# %%
matplotlib.rcParams.update({'font.size': 10})
fig = plt.figure(constrained_layout=True,figsize=(5,5))
#sns.despine()

gs = GridSpec(1, 1, figure=fig)
#ax1 = fig.add_subplot(gs[0, 0:])
ax2 = fig.add_subplot(gs[0, 0])
#ax1.annotate('a', (-1,1.05), size=5, xycoords=ax1.get_xaxis_transform(), weight='bold')
#ax2.annotate('b', (-42,1.03), size=15, xycoords=ax2.get_xaxis_transform(), weight='bold')
#ax6.annotate('c', (0,1.01), size=5, xycoords=ax6.get_xaxis_transform(), weight='bold')

#ax1.imshow(fig1a)
#ax1.set_axis_off()

ax2 = sc.pl.umap(ad_sub, color=['show_OL'],ax=ax2,legend_loc = None,\
           legend_fontsize=10,title=' ', show=False, size=5, frameon = False)

#ax2.spines['bottom'].set_color('#000000')
#ax2.spines['left'].set_color('#000000') 
#ax2.spines['top'].set_color('#FFFFFF')
#ax2.spines['right'].set_color('#FFFFFF')
#ax2.set_facecolor('white')

#ax2.xaxis.label.set_size(12)
#ax2.yaxis.label.set_size(12)

# %%
matplotlib.rcParams.update({'font.size': 10})
fig = plt.figure(constrained_layout=True,figsize=(5,5))
#sns.despine()

gs = GridSpec(1, 1, figure=fig)
#ax1 = fig.add_subplot(gs[0, 0:])
ax2 = fig.add_subplot(gs[0, 0])
#ax1.annotate('a', (-1,1.05), size=5, xycoords=ax1.get_xaxis_transform(), weight='bold')
#ax2.annotate('b', (-42,1.03), size=15, xycoords=ax2.get_xaxis_transform(), weight='bold')
#ax6.annotate('c', (0,1.01), size=5, xycoords=ax6.get_xaxis_transform(), weight='bold')

#ax1.imshow(fig1a)
#ax1.set_axis_off()

ax2 = sc.pl.draw_graph(ad_zc, color = ['label_13'],legend_loc = 'on data',show = False,
                       ax = ax2, legend_fontoutline = 3,frameon = False, edges = True)
#ax2.spines['bottom'].set_color('#000000')
#ax2.spines['left'].set_color('#000000') 
#ax2.spines['top'].set_color('#FFFFFF')
#ax2.spines['right'].set_color('#FFFFFF')
#ax2.set_facecolor('white')

#ax2.xaxis.label.set_size(12)
#ax2.yaxis.label.set_size(12)

# %%
sc.pl.draw_graph(ad_zc, color = gene_list[0],title = gene_list[0], legend_loc = None,\
                       legend_fontoutline = 3,frameon = False, edges_width = 0.05,edges = True,
                      show = False, cmap = cm ,vmin = -0.8, vmax = 3, s = 10)
# Out:
# <AxesSubplot:title={'center':'RASGRF2'}, xlabel='FA1', ylabel='FA2'>

# %%
matplotlib.rcParams.update({'font.size': 8})
fig = plt.figure(figsize=(10,2))
#sns.despine()

gs = GridSpec(1,5, figure=fig)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])
ax4 = fig.add_subplot(gs[0, 3])
ax5 = fig.add_subplot(gs[0, 4])
#ax6 = fig.add_subplot(gs[2, 1])


#ax1.annotate('a', (-1,1.05), size=5, xycoords=ax1.get_xaxis_transform(), weight='bold')
#ax2.annotate('b', (-42,1.03), size=15, xycoords=ax2.get_xaxis_transform(), weight='bold')
#ax6.annotate('c', (0,1.01), size=5, xycoords=ax6.get_xaxis_transform(), weight='bold')

#ax1.imshow(fig1a)
#ax1.set_axis_off()
cm = 'RdGy_r'

gene_list = ['RASGRF2','NPTX2','MKI67','C1QL1','MOG']
ax1 = sc.pl.draw_graph(ad_zc, color = gene_list[0],title = gene_list[0], legend_loc = None,\
                       legend_fontoutline = 3,frameon = False, edges = True,edges_width = 0.01,
                      ax = ax1, show = False, cmap = cm ,vmin = -0.8, vmax = 3, s = 10)

ax2 = sc.pl.draw_graph(ad_zc, color = gene_list[1],title = gene_list[1], legend_loc = None,\
                       legend_fontoutline = 3,frameon = False, edges = True,edges_width = 0.01,
                      ax = ax2, show = False, cmap = cm ,vmin = -1, vmax = 3, s = 10)

ax3 = sc.pl.draw_graph(ad_zc, color = gene_list[2],title = gene_list[2], legend_loc = None,\
                       legend_fontoutline = 3,frameon = False, edges = True,edges_width = 0.01,
                      ax = ax3, show = False, cmap = cm ,vmin = -0.5, vmax = 3, s = 10)
ax4 = sc.pl.draw_graph(ad_zc, color = gene_list[3],title = gene_list[3], legend_loc = None,\
                       legend_fontoutline = 3,frameon = False, edges = True,edges_width = 0.01,
                      ax = ax4, show = False, cmap = cm ,vmin = -1.5, vmax = 5)
ax5 = sc.pl.draw_graph(ad_zc, color = gene_list[4],title = gene_list[4], legend_loc = None,\
                       legend_fontoutline = 3,frameon = False, edges = True,edges_width = 0.01,
                      ax = ax5, show = False, cmap = cm ,vmin = -1.5, vmax = 4)

#ax2.spines['bottom'].set_color('#000000')
#ax2.spines['left'].set_color('#000000') 
#ax2.spines['top'].set_color('#FFFFFF')
#ax2.spines['right'].set_color('#FFFFFF')
#ax2.set_facecolor('white')

#ax2.xaxis.label.set_size(12)
#ax2.yaxis.label.set_size(12)


#fig.tight_layout(w_pad=0.3)
#plt.show()
plt.savefig("Figure/V4/Fig4_Astro_OPC/Fig4_opc_5marker.pdf", dpi = 200)
plt.savefig("Figure/V4/Fig4_Astro_OPC/Fig4_opc_5marker.png", dpi = 600)
