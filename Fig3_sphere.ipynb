# %%
# %pylab inline

import warnings
warnings.filterwarnings("ignore")
import pickle
from SCCAF import *
from NaiveDE import *
import scanpy as sc
import harmonypy as hm
from sklearn.preprocessing import scale
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def add_one_cluster(ad,key_level, key):
    #high light selected cluster
    ad.obs['class_show'] = (ad.obs[key_level]== key)
    ad.obs['class_show'] = ad.obs['class_show'].astype(str)
    ad.uns['class_show_colors'] = ['#d3d3d3','#cc3300']
    sc.pl.umap(ad, color = [key_level,'class_show'], title = [key_level,key])

# %% [markdown]
# # load data

# %%
FM_sphere=sc.read('data/SCCAF/FM_sphere_6988_SCCAF_all_cell_label9_2.h5')

# %%
FM_sphere.obsm['X_umap'] = -FM_sphere.obsm['X_umap4']

matplotlib.rcParams.update({'font.size': 10})
fig = plt.figure(constrained_layout=True,figsize=(10,3.5))
#sns.despine()

gs = GridSpec(2,7, figure=fig)
ax1 = fig.add_subplot(gs[0:2, 0:2])
ax2 = fig.add_subplot(gs[0, 2])
ax3 = fig.add_subplot(gs[0,3 ])
ax4 = fig.add_subplot(gs[0,4 ])
ax5 = fig.add_subplot(gs[0,5 ])
ax6 = fig.add_subplot(gs[0,6 ])
ax7 = fig.add_subplot(gs[1,2 ])
ax8 = fig.add_subplot(gs[1,3 ])
ax9 = fig.add_subplot(gs[1,4 ])
ax10 = fig.add_subplot(gs[1,5 ])
ax11 = fig.add_subplot(gs[1,6 ])



#ax5 = fig.add_subplot(gs[0:, 3])
#ax6 = fig.add_subplot(gs[2, 3:35])
#ax1.annotate('a', (-1,1.05), size=5, xycoords=ax1.get_xaxis_transform(), weight='bold')
#ax2.annotate('b', (-42,1.03), size=15, xycoords=ax2.get_xaxis_transform(), weight='bold')
#ax6.annotate('c', (0,1.01), size=5, xycoords=ax6.get_xaxis_transform(), weight='bold')

#ax1.imshow(fig1a)
#ax1.set_axis_off()

ax1 = sc.pl.umap(FM_sphere, color = 'marker1_predict_harmony', title = 'SCCAF Projection', \
                 ax = ax1,legend_loc = None, frameon = False, show = False)
ax2 = sc.pl.umap(FM_sphere, color = 'IPC', title = 'IPC',\
                 ax = ax2,legend_loc = None, frameon = False, show = False)

ax3 = sc.pl.umap(FM_sphere, color = 'Neuroblast', title = 'Neuroblast',\
                 ax = ax3,legend_loc = None, frameon = False, show = False)
ax4 = sc.pl.umap(FM_sphere, color = 'Granule_immature', title = 'GC_immature',\
                 ax = ax4,legend_loc = None, frameon = False, show = False)
ax5 = sc.pl.umap(FM_sphere, color = 'Granule_mature', title = 'GC_mature', \
                 ax = ax5,legend_loc = None, frameon = False, show = False)
ax6 = sc.pl.umap(FM_sphere, color = 'Granule_mature_1', title = 'GC_mature_1',\
                 ax = ax6,legend_loc = None, frameon = False, show = False)
ax7 = sc.pl.umap(FM_sphere, color = 'Astro_progenitor', title = 'Astro_pro',\
                 ax = ax7,legend_loc = None, frameon = False, show = False)
ax8 = sc.pl.umap(FM_sphere, color = 'Astro_progenitor_1', title = 'Astro_pro1',\
                 ax = ax8,legend_loc = None, frameon = False, show = False)
ax9 = sc.pl.umap(FM_sphere, color = 'Astro_progenitor_2', title = 'Astro_pro2', \
                 ax = ax9,legend_loc = None, frameon = False, show = False)
ax10 = sc.pl.umap(FM_sphere, color = 'Astro_1', title = 'Astro_1',\
                  ax = ax10,legend_loc = None, frameon = False, show = False)
ax11 = sc.pl.umap(FM_sphere, color = 'Astro_2', title = 'Astro_2',\
                  ax = ax11,legend_loc = None, frameon = False, show = False)

#matplotlib.rcParams.update({'font.size': 4})
#ax6 = sns.heatmap(plot_gene_matrix, cmap = cm,xticklabels = 1, yticklabels = 1,cbar = False)
#fig.tight_layout(w_pad=0.3)

# %%
FM_sphere.obsm['X_umap'] = -FM_sphere.obsm['X_umap4']

matplotlib.rcParams.update({'font.size': 10})
fig = plt.figure(constrained_layout=True,figsize=(10,3.5))
#sns.despine()

gs = GridSpec(2,7, figure=fig)
ax1 = fig.add_subplot(gs[0:2, 0:2])
ax2 = fig.add_subplot(gs[0, 2])
ax3 = fig.add_subplot(gs[0,3 ])
ax4 = fig.add_subplot(gs[0,4 ])
ax5 = fig.add_subplot(gs[0,5 ])
ax6 = fig.add_subplot(gs[0,6 ])
ax7 = fig.add_subplot(gs[1,2 ])
ax8 = fig.add_subplot(gs[1,3 ])
ax9 = fig.add_subplot(gs[1,4 ])
ax10 = fig.add_subplot(gs[1,5 ])
ax11 = fig.add_subplot(gs[1,6 ])



ax1 = sc.pl.umap(FM_sphere[FM_sphere.obs['marker1_predict_harmony'].sort_values().index.tolist(),:], color = 'marker1_predict_harmony', title = 'SCCAF Projection', \
                 ax = ax1,legend_loc = None, frameon = False, show = False)
ax2 = sc.pl.umap(FM_sphere[FM_sphere.obs['IPC'].sort_values().index.tolist(),:], color = 'IPC', title = 'IPC',\
                 ax = ax2,legend_loc = None, frameon = False, show = False)
ax3 = sc.pl.umap(FM_sphere[FM_sphere.obs['Neuroblast'].sort_values().index.tolist(),:], color = 'Neuroblast', title = 'Neuroblast',\
                 ax = ax3,legend_loc = None, frameon = False, show = False)
ax4 = sc.pl.umap(FM_sphere[FM_sphere.obs['Granule_immature'].sort_values(ascending=False).index.tolist(),:], color = 'Granule_immature', title = 'GC_immature',\
                 ax = ax4,legend_loc = None, frameon = False, show = False)
ax5 = sc.pl.umap(FM_sphere[FM_sphere.obs['Granule_mature'].sort_values(ascending=False).index.tolist(),:], color = 'Granule_mature', title = 'GC_mature', \
                 ax = ax5,legend_loc = None, frameon = False, show = False)
ax6 = sc.pl.umap(FM_sphere[FM_sphere.obs['Granule_mature_1'].sort_values(ascending=False).index.tolist(),:], color = 'Granule_mature_1', title = 'GC_mature_1',\
                 ax = ax6,legend_loc = None, frameon = False, show = False)
ax7 = sc.pl.umap(FM_sphere[FM_sphere.obs['Astro_progenitor'].sort_values(ascending=False).index.tolist(),:], color = 'Astro_progenitor', title = 'APC',\
                 ax = ax7,legend_loc = None, frameon = False, show = False)
ax8 = sc.pl.umap(FM_sphere[FM_sphere.obs['Astro_progenitor_1'].sort_values(ascending=False).index.tolist(),:], color = 'Astro_progenitor_1', title = 'APC_1',\
                 ax = ax8,legend_loc = None, frameon = False, show = False)
ax9 = sc.pl.umap(FM_sphere[FM_sphere.obs['Astro_progenitor_2'].sort_values(ascending=False).index.tolist(),:], color = 'Astro_progenitor_2', title = 'APC_2', \
                 ax = ax9,legend_loc = None, frameon = False, show = False)
ax10 = sc.pl.umap(FM_sphere[FM_sphere.obs['Astro_1'].sort_values(ascending=False).index.tolist(),:], color = 'Astro_1', title = 'Astro_1',\
                  ax = ax10,legend_loc = None, frameon = False, show = False)
ax11 = sc.pl.umap(FM_sphere[FM_sphere.obs['Astro_2'].sort_values(ascending=False).index.tolist(),:], color = 'Astro_2', title = 'Astro_2',\
                  ax = ax11,legend_loc = None, frameon = False, show = False)

plt.savefig("Figure/V5/Fig2_Neuron/Fig_sphere_umap4_sorted.pdf", dpi = 600)
plt.savefig("Figure/V5/Fig2_Neuron/Fig_sphere_umap4_sorted.png", dpi = 600)

#sort created by TL

# %%
matplotlib.rcParams.update({'font.size': 14})
fig = plt.figure(figsize=(13,5))
#sns.despine()

gs = GridSpec(2,4, figure=fig)
#ax1 = fig.add_subplot(gs[0, 0:])
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])
ax4 = fig.add_subplot(gs[0, 3])
# ax5 = fig.add_subplot(gs[0, 4])

ax5 = fig.add_subplot(gs[1, 0])
ax6 = fig.add_subplot(gs[1, 1])
ax7 = fig.add_subplot(gs[1, 2])
ax8 = fig.add_subplot(gs[1, 3])
# ax10 = fig.add_subplot(gs[1, 4])




#ax1.annotate('a', (-1,1.05), size=5, xycoords=ax1.get_xaxis_transform(), weight='bold')
#ax2.annotate('b', (-42,1.03), size=15, xycoords=ax2.get_xaxis_transform(), weight='bold')
#ax6.annotate('c', (0,1.01), size=5, xycoords=ax6.get_xaxis_transform(), weight='bold')

#ax1.imshow(fig1a)
#ax1.set_axis_off()

gl = ['HMGB2','MKI67','NNAT','SOX4',\
      'SLC1A3','SDC4','RSPO3','PAX6']

vmn = [-0.7,-0.8,-0.4,-0.6,
       -0.7,-0.7,-0.6,-0.11]
vmx = [2.1,2.4,1.2,1.8,
       2.1,2.1,1.8,0.4]
#ax1 = sc.pl.umap(ad,  show=False, ax = ax1)
ax1 = sc.pl.umap(FM_sphere, color=gl[0],ax=ax1,legend_loc = 'none',cmap = 'RdGy_r',vmin = vmn[0], vmax = vmx[0],\
           legend_fontsize=10,title=gl[0], show=False,  frameon = False, s = 12)

ax2 = sc.pl.umap(FM_sphere, color=gl[1],ax=ax2,legend_loc = 'none',cmap = 'RdGy_r',vmin = vmn[1],vmax = vmx[1], \
           legend_fontsize=10,title=gl[1], show=False, frameon = False,s = 12)

ax3 = sc.pl.umap(FM_sphere, color=gl[2],ax=ax3,legend_loc = 'none',cmap = 'RdGy_r',vmin = vmn[2],vmax = vmx[2], \
           legend_fontsize=10,title=gl[2], show=False,  frameon = False,s = 12)

ax4 = sc.pl.umap(FM_sphere, color=gl[3],ax=ax4,legend_loc = 'none',cmap = 'RdGy_r',vmin = vmn[3], vmax = vmx[3],\
           legend_fontsize=10,title=gl[3], show=False,  frameon = False,s = 12)

ax5 = sc.pl.umap(FM_sphere, color=gl[4],ax=ax5,legend_loc = 'none',cmap = 'RdGy_r',vmin = vmn[4],vmax = vmx[4], \
           legend_fontsize=10,title=gl[4], show=False,  frameon = False,s = 12)

ax6 = sc.pl.umap(FM_sphere, color=gl[5],ax=ax6,legend_loc = 'none',cmap = 'RdGy_r',vmin = vmn[5], vmax = vmx[5],\
           legend_fontsize=10,title=gl[5], show=False,  frameon = False,s = 12)

ax7 = sc.pl.umap(FM_sphere, color=gl[6],ax=ax7,legend_loc = 'none',cmap = 'RdGy_r',vmin = vmn[6], vmax = vmx[6],\
           legend_fontsize=10,title=gl[6], show=False,  frameon = False,s = 12)

ax8 = sc.pl.umap(FM_sphere, color=gl[7],ax=ax8,legend_loc = 'none',cmap = 'RdGy_r',vmin = vmn[7], vmax = vmx[7],\
           legend_fontsize=10,title=gl[7], show=False, frameon = False,s = 12)

# ax9 = sc.pl.umap(FM_sphere, color=gl[8],ax=ax9,legend_loc = 'none',cmap = 'RdGy_r',vmin = vmn[8], vmax = vmx[8],\
#            legend_fontsize=10,title=gl[8], show=False,  frameon = False)

# ax10 = sc.pl.umap(FM_sphere, color=gl[9],ax=ax10,legend_loc = 'none',cmap = 'RdGy_r',vmin = vmn[9], vmax = vmx[9],\
#            legend_fontsize=10,title=gl[9], show=False,  frameon = False)



#ax2.spines['bottom'].set_color('#000000')
#ax2.spines['left'].set_color('#000000') 
#ax2.spines['top'].set_color('#FFFFFF')
#ax2.spines['right'].set_color('#FFFFFF')
#ax2.set_facecolor('white')

#ax2.xaxis.label.set_size(12)
#ax2.yaxis.label.set_size(12)


#fig.tight_layout(w_pad=0.01)
#plt.show()
plt.savefig("Figure/V8_cell/Fig_Sphere/sphere_markergenes_8_2.pdf", dpi = 200)
plt.savefig("Figure/V8_cell/Fig_Sphere/sphere_markergenes_8_2.png", dpi = 600)

# %%
#FM_sphere.write('data/SCCAF/FM_sphere_6988_SCCAF_all_cell_label9_umap5.h5')
FM_sphere = sc.read('data/SCCAF/FM_sphere_6988_SCCAF_all_cell_label9_umap5.h5')
